# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
FOLDERNAME = 'cs231n/'
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/cs231n

# %%
# !git init
# !git config --global user.email ""
# !git config --global user.name "lyu"
# Out:
# Initialized empty Git repository in /content/drive/My Drive/cs231n/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@453f5c8fe9bc.(none)')
# error: refname refs/heads/master not found
# fatal: Branch rename failed
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://github.com/dbtmddn41/cs231n.git'

# %%
# !git add *
# !git commit -m "from drive"
# !git branch -M main
# !git remote add origin https://github.com/dbtmddn41/cs231n.git
# !git push -u origin main
