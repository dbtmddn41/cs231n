# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
FOLDERNAME = 'cs231n/'
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/cs231n

# %%
# !git init
# !git config --global user.email "dbtmddn41@gmail.com"
# !git config --global user.name "Lyu"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/cs231n/.git/

# %%
# !git add *
# !git commit -m "from drive"

# %%
# !git branch -M main
# !git remote rm github
# !git remote add github https://dbtmddn41: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@github.com/dbtmddn41/cs231n.git

# %%
# !git push -u github main
# Out:
# Counting objects: 61, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (59/59), done.
# Writing objects: 100% (61/61), 165.27 MiB | 9.50 MiB/s, done.
# Total 61 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/dbtmddn41/cs231n.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'github'.
